# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("YT.csv", encoding="latin1")

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
df.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# ...

# %%
df.isna().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
pd.set_option('display.float_format','{:.2f}'.format)

# %%
#category wise subscribers
category_sub_mean = df.groupby('category')['subscribers'].mean()

# %%
category_sub_mean
# Out:
# category
# Autos & Vehicles        17850000.00
# Comedy                  20123188.41
# Education               26542222.22
# Entertainment           21403319.50
# Film & Animation        28584782.61
# Gaming                  20852127.66
# Howto & Style           19390000.00
# Movies                  25650000.00
# Music                   25717821.78
# News & Politics         20630769.23
# Nonprofits & Activism   27750000.00
# People & Blogs          21056060.61
# Pets & Animals          18100000.00
# Science & Technology    18617647.06
# Shows                   41615384.62
# Sports                  27109090.91
# Trailers                39000000.00
# Travel & Events         12500000.00
# Name: subscribers, dtype: float64

# %%
category_sub_mean.sort_values(ascending=False,inplace=True)

# %%
category_sub_mean.plot(kind='bar')
plt.title('category wise mean subscribers')
plt.xlabel('category')
plt.ylabel('Mean subscribers')
plt.show()

# %%
channel_type_count=df['channel_type'].value_counts()

# %%
channel_type_count
# Out:
# channel_type
# Entertainment    304
# Music            216
# People           101
# Games             98
# Comedy            51
# Education         49
# Film              42
# Howto             36
# News              30
# Tech              17
# Sports            13
# Autos              3
# Animals            3
# Nonprofit          2
# Name: count, dtype: int64

# %%
channel_type_count.head().plot(kind='pie',autopct='%1.1f%%')
plt.title('channel wise Distribution')
plt.show()

# %%
plt.scatter(df['subscribers'],df['video views'])
plt.title("scatter plot between subscribers and video views")
plt.xlabel('Subscribers')
plt.ylabel('Views')
# Out:
# Text(0, 0.5, 'Views')

# %%
#category wise views to the channel

category_wise_views=df.groupby('category')['subscribers'].mean()

# %%
category_wise_views.plot(kind='bar')
plt.title('category wise views')
plt.xlabel('category')
plt.ylabel('views')
plt.show()

# %%
#contry wise subscribers distribution
Country_wise_subscribers_total = df.groupby('Country')['subscribers'].sum()

# %%
# Top 10 contries subscribers to youtube
Country_wise_subscribers_total.sort_values(ascending=False).head(10).plot(kind='bar')
plt.title('Top 10 YouTube subscribing countries ')
plt.show()

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
# channels created per year 

# year wise channel creation trend 
channels_per_year = df.groupby('created_year')['Youtuber'].count()

plt.figure(figsize=(15,8))
sns.barplot(x=channels_per_year.index, y=channels_per_year.values)
plt.xlabel("Year")
plt.ylabel("Number of Channels Created")
plt.title("YouTube Channels Created Over the Years")
plt.grid(True)
plt.show()

# %%
year_wise_unemployment_rate=df.groupby('created_year')['Unemployment rate'].mean()
plt.figure(figsize=(10,6))
sns.lineplot(x=year_wise_unemployment_rate.index, y=year_wise_unemployment_rate.values, marker='o', color="red")
plt.xlabel("Year")
plt.ylabel("Average Unemployment Rate (%)")
plt.title("Yearly Trend of Unemployment Rate")
plt.grid(True)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(12,6))

# 📊 Bar chart for number of channels created
channels_per_year = df['created_year'].value_counts().sort_index()
ax1.bar(channels_per_year.index, channels_per_year.values, color='blue', alpha=0.6, label='Channels Created')
ax1.set_xlabel("Year")
ax1.set_ylabel("Number of Channels Created", color="blue")
ax1.tick_params(axis='y', labelcolor="blue")

# 📉 Line chart for unemployment rate
ax2 = ax1.twinx()
ax2.plot(year_wise_unemployment_rate.index, year_wise_unemployment_rate.values, marker='o', color='red', label='Unemployment Rate')
ax2.set_ylabel("Unemployment Rate (%)", color="red")
ax2.tick_params(axis='y', labelcolor="red")

# 📌 Titles and Grid
plt.title("YouTube Channel Creation vs. Unemployment Rate")
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

# 🔹 Legends
ax1.legend(loc="upper left")
ax2.legend(loc="upper right")

plt.show()

# %%
# In above fig observer can notice that as channel 
# created increases unemployment rate decreases
# YouTube helps to increase employment

# %%
#Highest monthly earnings by channel type
sns.boxplot(x='channel_type',y='highest_monthly_earnings',data=df)
plt.title('highest earning by channel type')
plt.xticks(rotation=90)
plt.show()
